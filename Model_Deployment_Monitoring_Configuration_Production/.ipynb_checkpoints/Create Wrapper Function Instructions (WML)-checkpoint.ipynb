# %% [markdown]
# # Create Wrapper Function for WML Deployment

# %% [markdown]
# ## Overview
# In this notebook you will create a wrapper function for a model deployed in Watson Machine Learning (WML).  This function checks whether the model usability status in OpenPages is set to "Allow" before calling the WML endpoint.

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# 1. Your WML model deployment already exists.
# 2. An OpenPages model entry has been created for this model.

# %% [markdown]
# ## Steps

# %% [markdown]
# ### 1. Open the provided JSON file 'wrapper_config_wml_template.json' in a text editor.  Fill in each of the required parameters as described below:
#     - "wml_endpoint" : REST endpoint for model that is already deployed in WML
#     - "cpd_username" : Cloud Pak for Data username
#     - "cpd_api_key" : Cloud Pak for Data user API Key
#     - "deployment_space": Name of WML deployment space where wrapper function should be stored
#     - "function_name": Desired name of wrapper function
#     - "deployment_name": Desired name of deployment for wrapper function
#     - "op_api_key": OpenPages API Key
#     - "model_status_field": Name of usability status field in OpenPages (use "MRG-Model:Usability Status")
#     - "mrm_model_id": Corresponding MRM model ID in OpenPages
# See the sample parameter values below for guidance (api keys omitted):

# %% [markdown]
# ![Screen%20Shot%202021-09-08%20at%203.53.52%20PM.png](attachment:Screen%20Shot%202021-09-08%20at%203.53.52%20PM.png)

# %% [markdown]
# ### 2. Save the JSON file locally, then upload the JSON file to your model development project in Cloud Pak for Data using the file upload UI on the righthand side of the project homepage.  Choose the 'browse' option and select the JSON file that you saved locally.
#
# ![Screen%20Shot%202021-09-08%20at%202.32.39%20PM.png](attachment:Screen%20Shot%202021-09-08%20at%202.32.39%20PM.png)

# %% [markdown]
# ### 3. Upload the provided notebook 'Create Wrapper Function (WML).ipynb' to your CPD project.  To do so, from the project homepage select the 'Add to project + ' box in blue on the top righthand side.  Choose 'notebook', and then navigate to the 'From file' tab in the following screen:
# ![Screen%20Shot%202021-09-08%20at%202.37.43%20PM.png](attachment:Screen%20Shot%202021-09-08%20at%202.37.43%20PM.png)

# %% [markdown]
# ### 4. Select 'Drag and drop files here or upload'.  Then navigate to the notebook on your local system, leave the notebook name as is (Create Wrapper Function (WML)) and then select 'Create' in the bottom righthand corner to upload to the project.
# ![Screen%20Shot%202021-09-08%20at%202.37.43%20PM.png](attachment:Screen%20Shot%202021-09-08%20at%202.37.43%20PM.png)

# %% [markdown]
# ### 5. Upon uploading the notebook, the notebook should automatically open in edit mode with an active runtime.  From within the notebook, navigate to the 'File' menu and select 'Save Version':
# ![Screen%20Shot%202021-09-08%20at%203.45.22%20PM.png](attachment:Screen%20Shot%202021-09-08%20at%203.45.22%20PM.png)

# %% [markdown]
# ### 6. Select the icon with a window and a play button in the top righthand corner.  Then select 'Create a job':
# ![Screen%20Shot%202021-09-08%20at%203.46.50%20PM.png](attachment:Screen%20Shot%202021-09-08%20at%203.46.50%20PM.png)

# %% [markdown]
# ### 7. Give the job a name ('Create Wrapper Function WML Job'), then select 'Next' in the bottom righthand corner.

# %% [markdown]
# ![Screen%20Shot%202021-09-08%20at%203.47.55%20PM.png](attachment:Screen%20Shot%202021-09-08%20at%203.47.55%20PM.png)

# %% [markdown]
# ### 8. In the Configure section, leave the default values for 'Select version' ('latest') and 'Select environment' ('Default Python 3.7').  Then select the 'Advanced configuration' checkbox below the environment selection.  In the box that appears, enter the following: CONFIG_FILE=wrapper_config_wml.json .  Use the exact name of the JSON file that you uploaded to the project in Step 2.  Then select 'Next' in the bottom righthand corner.
# ![Screen%20Shot%202021-09-08%20at%203.50.17%20PM.png](attachment:Screen%20Shot%202021-09-08%20at%203.50.17%20PM.png)

# %% [markdown]
# ### 9. Leave the schedule screen as is ('Schedule Off'). Then select 'Next'.
# ![Screen%20Shot%202021-09-08%20at%203.51.11%20PM.png](attachment:Screen%20Shot%202021-09-08%20at%203.51.11%20PM.png)

# %% [markdown]
# ### 10. Select 'Create and Run' in the bottom righthand corner.  This will trigger the wrapper function to be created using the parameters that you provided.  Wait a couple of minutes for the job to complete.
# ![Screen%20Shot%202021-09-08%20at%203.51.37%20PM.png](attachment:Screen%20Shot%202021-09-08%20at%203.51.37%20PM.png)

# %% [markdown]
# ### 11. Once the job is complete, you can verify the function was created successfully by navigating to the deployment space and selecting the deployment with the name that you provided in the configuration JSON.  Select the 'Test' tab for the deployment.  Here you can send a sample scoring request to the deployment to verify that the prediction response is as expected.  To do so, paste the following into the 'Enter input data' section.  Then select 'Predict' and confirm that predictions are as expected.

# %%
{"input_data":[{"fields":["DAY","DAY_OF_WEEK","ORIGIN_AIRPORT","DESTINATION_AIRPORT","DEPARTURE_DELAY","TAXI_OUT","DISTANCE"],"values":[[11,7,"ABQ","DFW",2,11,570],[11,7,"ABQ","DFW",2,11,570]]}]}
# Out:
# {'input_data': [{'fields': ['DAY',
#     'DAY_OF_WEEK',
#     'ORIGIN_AIRPORT',
#     'DESTINATION_AIRPORT',
#     'DEPARTURE_DELAY',
#     'TAXI_OUT',
#     'DISTANCE'],
#    'values': [[11, 7, 'ABQ', 'DFW', 2, 11, 570],
#     [11, 7, 'ABQ', 'DFW', 2, 11, 570]]}]}

# %% [markdown]
# ![Screen%20Shot%202021-09-08%20at%204.06.49%20PM.png](attachment:Screen%20Shot%202021-09-08%20at%204.06.49%20PM.png)
