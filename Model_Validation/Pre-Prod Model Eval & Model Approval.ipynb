# %% [markdown]
# ## Pre-Prod Model Evaluation & Approval
#
#
# #### This sub-step involves evaluating the models deployed in pre-prod/UAT environment using Openscale and comparing different models to decide the optimal model to be moved to production in later steps.

# %% [markdown]
# ### Step 1. Pre-prod Model Evaluation
#
# + After you are done with configuring the model parameters, you have to evaluate the Model by passing the Feedback data.
#
# + Click on the `Model Summary` under the Model Info and Evaluation sections on the left pane.
#
# + Click on the `Actions` drop down on the right and select `Evaluate Now`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <br>
#
# + Under the Import test data section select Import `from CSV file` and browse for the "Validation Dataset” provided to you.
#
# + This is stored in your “Model-Catalog-`GroupNumber` Catalog which you can download into your system.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <br><br>
# + Once you have uploaded the feedback file and clicked on `Upload and Evaluate`, it may take some time to generate the performance statistics (Fairness/Quality/Drift)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <br><br>
#
# ### Step 2. Model Approval
#
# + Once you're satisfied with the deployed model and its performance, approve the model for production (again going through the link in the `Actions` drop down menu).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <br>
#
# + You may also download the Report PDF showcasing the statistics of the chosen model and its associated summary from the link in the `Actions` drop down menu.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Step 3. Sending Report to IBM Openpages
#
#
# In order to evaluate the model usability, you can send the report and performance metrics to Openpages as shown in the figures below:
#
#
# ![Screen%20Shot%202021-09-13%20at%206.03.35%20PM.png](attachment:Screen%20Shot%202021-09-13%20at%206.03.35%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202021-09-13%20at%206.03.53%20PM.png](attachment:Screen%20Shot%202021-09-13%20at%206.03.53%20PM.png)

# %% [markdown]
# <br><br>
#
# ### Step 4. Model Comparison (Optional)
#
# Note: This step is optional. It involves comparing the performance metrics of multiple models.  You can create another model using a different algorithm and evaluate it with the validation dataset. Perform the steps below If you have deployed more than one model in your pre-prod-deployment space.
#
# - Model comparison steps are shown in the pictures below.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# + Select the model for comparison and compare the stats.

# %% [markdown]
# ![image.png](attachment:image.png)
